# %%
import sys

# input = sys.stdin.readline
N, K = map(int, input().split())

move = [0]*100001

def bfs(n, K):
    global cnt
    if n == K:
        return True
    cnt+=1
    print(cnt)
    if n*2 <= K:
        bfs(n*2, K)
    elif n+1 <= K:
        bfs(n+1, K)
    else:
        bfs(n-1, K)
        
    return False    
        
    
if N == K:
    print(0)
else:
    cnt=0
    if bfs(N):
        print(cnt)
